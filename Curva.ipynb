# %%
voltaje(x)=170*sin(377*x)
show(plot(voltaje, (x, 0, 1/60),color='red'),figsize=10)
integral=numerical_integral((voltaje)^2, 0,1/60)[0]
rms=(1/(1/60)*integral)^0.5
print "rms",rms
# Out:
# Graphics object consisting of 1 graphics primitive
# rms 120.206736829163

# %%
voltaje(x)=325*sin(314*x)
show(plot(voltaje, (x, 0, pi/120),color='blue'),figsize=10)
integral=numerical_integral((voltaje)^2, 0,1/50)[0]
rms=(1/(1/50)*integral)^0.5
print "rms",rms
# Out:
# Graphics object consisting of 1 graphics primitive
# rms 229.867977512299

# %%
desfase=120/360*2*pi
voltajeR(x)=325*sin(314*x)
voltajeS(x)=325*sin(314*x+desfase)
voltajeRS=voltajeR-voltajeS
show(plot(voltajeR, (x, 0, pi/120),color='blue',figsize=10)+plot(voltajeS, (x, 0, pi/120),color='red'),figsize=10)
show(plot(voltajeRS, (x, 0, pi/120),color='green'),figsize=10)
integral=numerical_integral((voltajeRS)^2, 0,1/50)[0]
rms=(1/(1/50)*integral)^0.5
print "rms",rms
# Out:
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 1 graphics primitive
# rms 398.092274412027
